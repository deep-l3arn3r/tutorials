# %% [markdown]
# <a href="https://colab.research.google.com/github/deep-l3arn3r/tutorials/blob/NLP_Hf/nlp_ch1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from transformers import pipeline

classifier = pipeline("zero-shot-classification")

classifier(
    "This is a course about the Transformers library",
    candidate_labels=["education", "politics", "business"],
)
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli and revision c626438 (https://huggingface.co/facebook/bart-large-mnli).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# {'sequence': 'This is a course about the Transformers library',
#  'labels': ['education', 'business', 'politics'],
#  'scores': [0.8445989489555359, 0.11197412759065628, 0.04342695698142052]}

# %%
generator = pipeline("text-generation")
generator("In this course, we will teach you how to", num_return_sequences=2, max_length=15)
# Out:
# No model was supplied, defaulted to gpt2 and revision 6c0e608 (https://huggingface.co/gpt2).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'In this course, we will teach you how to use the OpenSSL program'},
#  {'generated_text': 'In this course, we will teach you how to create a Java platform environment'}]

# %%
from transformers import pipeline
unmasker = pipeline('fill-mask', model='bert-base-cased')
unmasker("This course will teach you all about [MASK] models.")
# Out:
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/436M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertForMaskedLM: ['bert.pooler.dense.bias', 'cls.seq_relationship.weight', 'bert.pooler.dense.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# tokenizer_config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]
# ...

# %%
summarizer = pipeline("summarization")
summarizer(
    """
    Just a few days before Christmas Eve, the US Federal Trade Commission (FTC) banned a struggling US pharmacy chain – Rite Aid – from using any kind of facial recognition Artificial Intelligence (AI) program for surveillance purposes in its stores for five years.

Rite Aid had deployed the technology between 2012 and 2020 in several of its stores. It says that it was primarily a pilot project – and had been discontinued. Unfortunately, during those years, the program threw up many false positives – flagging several perfectly innocent customers as potential shoplifters. The program had been deployed in a large number of Rite Aid stores in poorer neighbourhoods and it tended to falsely flag many customers as shoplifters. The imperfect technology led to a large number of shoppers being harassed by the staff of the shops, including being searched and questioned in front of family and friends. The program allegedly was racially biased and was prone to flagging non-white people as shoplifters.

The facial recognition software Rite Aid had started using was not made by any of the big names in AI. But Amazon, which has a pretty solid AI team and good credentials in using the technology for a long time, found an embarrassing bias in an AI algorithm that it had deployed to speed up hiring, and that showed up in the AI program Amazon had created for its hiring. Amazon had started using algorithms to shortlist good candidates for various open positions way back in 2015. The algorithms were trained to shortlist candidates who exhibited similar qualifications, job experience or traits. Amazon soon realised that AI was biased against women candidates – the algorithm had trained on the data on Amazon’s existing workforce, which had mostly men and it rejected even well-qualified women who applied.
    """
)
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# [{'summary_text': ' US Federal Trade Commission bans Rite Aid from using any kind of facial recognition Artificial Intelligence program for surveillance purposes in its stores for five years . The imperfect technology led to a large number of shoppers being harassed by staff of the shops, including being searched and questioned in front of family and friends . The program allegedly was racially biased and prone to flagging non-white people as shoplifters .'}]
